# %%
import pandas as pd
sms = pd.read_csv('sms_spam.csv')
sms.head()

print(sms.dtypes)
# Out:
# type    object
# text    object
# dtype: object

# %%
import re
def pre_process(info):
    #lowercase
    info = info.lower()
    #remove tags
    info=re.sub("</?.*?>"," <> ",info)
    # remove special characters and digits
    info=re.sub("(\\d|\\W)+"," ",info)
    return info

sms['info'] = sms['type'] + sms['text']
sms['info'] = sms['info'].apply(lambda x:pre_process(x))

sms['text'][:]
# Out:
# 0       Hope you are having a good week. Just checking in
# 1                                 K..give back my thanks.
# 2             Am also doing in cbe only. But have to pay.
# 3       complimentary 4 STAR Ibiza Holiday or £10,000 ...
# 4       okmail: Dear Dave this is your final notice to...
#                               ...
# 5554    You are a great role model. You are giving so ...
# 5555    Awesome, I remember the last time we got someb...
# 5556    If you don't, your prize will go to another cu...
# 5557    SMS. ac JSco: Energy is high, but u may not kn...
# 5558                      Shall call now dear having food
# Name: text, Length: 5559, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re

def get_stop_words(stop_file_path):
    """load stop words"""
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return frozenset(stop_set)
    
#load a set of stop words
stopwords=get_stop_words("sms_spam.csv")

#get the text column 
docs=sms['text'].tolist()

#create a vocabulary of words, 
#ignore words that appear in 85% of documents, 
#eliminate stop words
cv=CountVectorizer(max_df=0.85,stop_words=stopwords)
word_count_vector=cv.fit_transform(docs)
# Out:
# /Users/alonso/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['00', '000', '000pes', '008704050406', '0089', '0121', '01223585236', '01223585334', '0125698789', '02', '0207', '02072069400', '02073162414', '02085076972', '021', '03', '04', '0430', '05', '050703', '0578', '06', '07', '07008009200', '07046744435', '07090201529', '07090298926', '07099833605', '07123456789', '0721072', '07732584351', '07734396839', '07742676969', '07753741225', '0776xxxxxxx', '07781482378', '07786200117', '077xxx', '078', '07801543489', '07808', '07808247860', '07808726822', '07815296484', '07821230901', '078498', '07880867867', '0789xxxxxxx', '07946746291', '0796xxxxxx', '07973788240', '07xxxxxxxxx', '08', '0800', '08000407165', '08000776320', '08000839402', '08000930705', '08000938767', '08001950382', '08002888812', '08002986030', '08002986906', '08002988890', '08006344447', '0808', '08081263000', '08081560665', '0825', '083', '0844', '08448350055', '08448714184', '0845', '08450542832', '08452810071', '08452810073', '08452810075over18', '0870', '08700435505150p', '08700469649', '08700621170150p', '08701213186', '08701237397', '08701417012', '08701417012150p', '0870141701216', '087016248', '08701752560', '087018728737', '0870241182716', '08702490080', '08702840625', '08704050406', '08704439680', '08704439680ts', '08706091795', '0870737910216yrs', '08707500020', '08707509020', '0870753331018', '08707808226', '08708034412', '08708800282', '08709222922', '08709501522', '0871', '087104711148', '08712101358', '08712103738', '0871212025016', '08712300220', '087123002209am', '08712317606', '08712400200', '08712400602450p', '08712400603', '08712402050', '08712402578', '08712402779', '08712402902', '08712402972', '08712404000', '08712405020', '08712405022', '08712460324', '08712466669', '0871277810710p', '0871277810810', '0871277810910p', '08714342399', '087147123779am', '08714712379', '08714712388', '08714712394', '08714712412', '08714714011', '08715203028', '08715203649', '08715203652', '08715203656', '08715203677', '08715203685', '08715203694', '08715205273', '08715500022', '08715705022', '08717111821', '08717168528', '08717205546', '0871750', '08717507382', '08717509990', '08717890890', '08717895698', '08717898035', '08718711108', '08718720201', '08718723815', '08718725756', '08718726270', '087187262701', '08718726970', '08718726971', '08718726978', '087187272008', '08718727868', '08718727870', '08718727870150ppm', '08718730555', '08718730666', '08718738001', '08718738002', '08718738034', '08719180219', '08719180248', '08719181259', '08719181503', '08719181513', '08719839835', '08719899217', '08719899229', '08719899230', '09', '09041940223', '09050000301', '09050000332', '09050000460', '09050000555', '09050000878', '09050000928', '09050001295', '09050001808', '09050002311', '09050003091', '09050005321', '09050090044', '09050280520', '09053750005', '09056242159', '09057039994', '09058091854', '09058091870', '09058094454', '09058094455', '09058094507', '09058094565', '09058094583', '09058094594', '09058094597', '09058094599', '09058095107', '09058095201', '09058097189', '09058097218', '09058098002', '09058099801', '09061104276', '09061104283', '09061209465', '09061213237', '09061221061', '09061221066', '09061701444', '09061701461', '09061701851', '09061701939', '09061702893', '09061743386', '09061743806', '09061743810', '09061743811', '09061744553', '09061749602', '09061790121', '09061790125', '09061790126', '09063440451', '09063442151', '09063458130', '0906346330', '09064011000', '09064012103', '09064012160', '09064015307', '09064017295', '09064017305', '09064018838', '09064019014', '09064019788', '09065069120', '09065069154', '09065171142', '09065174042', '09065394514', '09065394973', '09065989180', '09065989182', '09066350750', '09066358152', '09066358361', '09066361921', '09066362206', '09066362220',  ...
#   'stop_words.' % sorted(inconsistent))

# %%
word_count_vector.shape
# Out:
# (5559, 8666)

# %%
cv=CountVectorizer(max_df=0.85,stop_words=stopwords,max_features=10000)
word_count_vector=cv.fit_transform(docs)
word_count_vector.shape
# Out:
# /Users/alonso/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['00', '000', '000pes', '008704050406', '0089', '0121', '01223585236', '01223585334', '0125698789', '02', '0207', '02072069400', '02073162414', '02085076972', '021', '03', '04', '0430', '05', '050703', '0578', '06', '07', '07008009200', '07046744435', '07090201529', '07090298926', '07099833605', '07123456789', '0721072', '07732584351', '07734396839', '07742676969', '07753741225', '0776xxxxxxx', '07781482378', '07786200117', '077xxx', '078', '07801543489', '07808', '07808247860', '07808726822', '07815296484', '07821230901', '078498', '07880867867', '0789xxxxxxx', '07946746291', '0796xxxxxx', '07973788240', '07xxxxxxxxx', '08', '0800', '08000407165', '08000776320', '08000839402', '08000930705', '08000938767', '08001950382', '08002888812', '08002986030', '08002986906', '08002988890', '08006344447', '0808', '08081263000', '08081560665', '0825', '083', '0844', '08448350055', '08448714184', '0845', '08450542832', '08452810071', '08452810073', '08452810075over18', '0870', '08700435505150p', '08700469649', '08700621170150p', '08701213186', '08701237397', '08701417012', '08701417012150p', '0870141701216', '087016248', '08701752560', '087018728737', '0870241182716', '08702490080', '08702840625', '08704050406', '08704439680', '08704439680ts', '08706091795', '0870737910216yrs', '08707500020', '08707509020', '0870753331018', '08707808226', '08708034412', '08708800282', '08709222922', '08709501522', '0871', '087104711148', '08712101358', '08712103738', '0871212025016', '08712300220', '087123002209am', '08712317606', '08712400200', '08712400602450p', '08712400603', '08712402050', '08712402578', '08712402779', '08712402902', '08712402972', '08712404000', '08712405020', '08712405022', '08712460324', '08712466669', '0871277810710p', '0871277810810', '0871277810910p', '08714342399', '087147123779am', '08714712379', '08714712388', '08714712394', '08714712412', '08714714011', '08715203028', '08715203649', '08715203652', '08715203656', '08715203677', '08715203685', '08715203694', '08715205273', '08715500022', '08715705022', '08717111821', '08717168528', '08717205546', '0871750', '08717507382', '08717509990', '08717890890', '08717895698', '08717898035', '08718711108', '08718720201', '08718723815', '08718725756', '08718726270', '087187262701', '08718726970', '08718726971', '08718726978', '087187272008', '08718727868', '08718727870', '08718727870150ppm', '08718730555', '08718730666', '08718738001', '08718738002', '08718738034', '08719180219', '08719180248', '08719181259', '08719181503', '08719181513', '08719839835', '08719899217', '08719899229', '08719899230', '09', '09041940223', '09050000301', '09050000332', '09050000460', '09050000555', '09050000878', '09050000928', '09050001295', '09050001808', '09050002311', '09050003091', '09050005321', '09050090044', '09050280520', '09053750005', '09056242159', '09057039994', '09058091854', '09058091870', '09058094454', '09058094455', '09058094507', '09058094565', '09058094583', '09058094594', '09058094597', '09058094599', '09058095107', '09058095201', '09058097189', '09058097218', '09058098002', '09058099801', '09061104276', '09061104283', '09061209465', '09061213237', '09061221061', '09061221066', '09061701444', '09061701461', '09061701851', '09061701939', '09061702893', '09061743386', '09061743806', '09061743810', '09061743811', '09061744553', '09061749602', '09061790121', '09061790125', '09061790126', '09063440451', '09063442151', '09063458130', '0906346330', '09064011000', '09064012103', '09064012160', '09064015307', '09064017295', '09064017305', '09064018838', '09064019014', '09064019788', '09065069120', '09065069154', '09065171142', '09065174042', '09065394514', '09065394973', '09065989180', '09065989182', '09066350750', '09066358152', '09066358361', '09066361921', '09066362206', '09066362220',  ...
#   'stop_words.' % sorted(inconsistent))
# (5559, 8666)

# %%
list(cv.vocabulary_.keys())[:]
# Out:
# ['hope',
#  'you',
#  'are',
#  'having',
#  'good',
#  'week',
#  'just',
#  'checking',
#  'in',
#  'give',
#  'back',
#  'my',
#  'thanks',
#  'am',
#  'also',
#  'doing',
#  'cbe',
#  'only',
#  'but',
#  'have',
#  'to',
#  'pay',
#  'complimentary',
#  'star',
#  'ibiza',
#  'holiday',
#  'or',
#  '10',
#  '000',
#  'cash',
#  'needs',
#  'your',
#  'urgent',
#  'collection',
#  '09066364349',
#  'now',
#  'from',
#  'landline',
#  'not',
#  'lose',
#  'out',
#  'box434sk38wp150ppm18',
#  'okmail',
#  'dear',
#  'dave',
#  'this',
#  'is',
#  'final',
#  'notice',
#  'collect',
#  'tenerife',
#  '5000',
#  'award',
#  'call',
#  '09061743806',
#  'tcs',
#  'sae',
#  'box326',
#  'cw25wx',
#  '150ppm',
#  'aiya',
#  'we',
#  'discuss',
#  'later',
#  'lar',
#  'pick',
#  'up',
#  'at',
#  'it',
#  'much',
#  'buzy',
#  'please',
#  'ask',
#  'mummy',
#  'father',
#  'marvel',
#  'mobile',
#  'play',
#  'the',
#  'official',
#  'ultimate',
#  'spider',
#  'man',
#  'game',
#  '50',
#  'on',
#  'ur',
#  'right',
#  'text',
#  '83338',
#  'for',
#  'll',
#  'send',
#  'free',
#  '8ball',
#  'wallpaper',
#  'fyi',
#  'usf',
#  'swing',
#  'by',
#  'room',
#  'whenever',
#  'sure',
#  'thing',
#  'big',
#  'hockey',
#  'elections',
#  'shouldn',
#  'go',
#  'longer',
#  'than',
#  'an',
#  'hour',
#  'though',
#  'anything',
#  'lor',
#  'march',
#  'ending',
#  'should',
#  'be',
#  'ready',
#  'will',
#  'problem',
#  'that',
#  'capital',
#  'never',
#  'complete',
#  'how',
#  'far',
#  'with',
#  'work',
#  'and',
#  'ladies',
#  'hmm',
#  'well',
#  'night',
#  'get',
#  'before',
#  'noon',
#  'see',
#  'what',
#  'ha',
#  'cool',
#  'chikku',
#  'db',
#  'darren',
#  'was',
#  'saying',
#  'dat',
#  'if',
#  'meeting',
#  'da',
#  'ge',
#  'den',
#  'dun',
#  'meet',
#  'dinner',
#  'cos',
#  'leave',
#  'xy',
#  'feel',
#  'awkward',
#  'him',
#  'lunch',
#  'he',
#  'dint',
#  'tell',
#  'angry',
#  'me',
#  'why',
#  'told',
#  'abi',
#  'wan',
#  'come',
#  'then',
#  'din',
#  'any',
#  'stripes',
#  'skirt',
#  'can',
#  'win',
#  '100',
#  'of',
#  'music',
#  'gift',
#  'vouchers',
#  'every',
#  'starting',
#  'txt',
#  'word',
#  'draw',
#  '87066',
#  'tscs',
#  'www',
#  'ldew',
#  'com',
#  'skillgame',
#  '1winaweek',
#  'age16',
#  '150ppermesssubscription',
#  '2mro',
#  'coming',
#  'gym',
#  'machan',
#  'goodnight',
#  'arr',
#  'birthday',
#  'today',
#  'wish',
#  'more',
#  'oscar',
#  'reading',
#  'gud',
#  'habit',
#  'nan',
#  'bari',
#  'hudgi',
#  'yorge',
#  'pataistha',
#  'ertini',
#  'kano',
#  'sent',
#  'scores',
#  'sophas',
#  'had',
#  'do',
#  'secondary',
#  'application',
#  'few',
#  'schools',
#  'think',
#  'thinking',
#  'applying',
#  'research',
#  'cost',
#  'contact',
#  'joke',
#  'ogunrinde',
#  'her',
#  'school',
#  'one',
#  'less',
#  'expensive',
#  'ones',
#  'could',
#  'read',
#  'love',
#  'answered',
#  'so',
#  'did',
#  'bank',
#  'say',
#  'about',
#  'money',
#  'desperate',
#  'armand',
#  'again',
#  'fuuuuck',
#  'need',
#  'stop',
#  'sleepin',
#  'sup',
#  'weather',
#  'over',
#  'there',
#  'ok',
#  'thanx',
#  'whats',
#  'todays',
#  'plan',
#  '1apple',
#  'day',
#  'no',
#  'doctor',
#  '1tulsi',
#  'leaf',
#  'cancer',
#  '1lemon',
#  'fat',
#  '1cup',
#  'milk',
#  'bone',
#  'problms',
#  'litres',
#  'watr',
#  'diseases',
#  'snd',
#  'ths',
#  'whom',
#  'care',
#  'sorry',
#  'exhausted',
#  'train',
#  'morning',
#  'too',
#  'wine',
#  'pie',
#  'sleep',
#  'won',
#  'nokia',
#  '6230',
#  'plus',
#  'digital',
#  'camera',
#  'when',
#  'our',
#  'auction',
#  'take',
#  'part',
#  '83383',
#  'pobox114',
#  '14tcr',
#  'w1',
#  '16',
#  'ron',
#  'fri',
#  'leh',
#  'said',
#  'ding',
#  'tai',
#  'feng',
#  'cant',
#  'make',
#  'reservations',
#  'wait',
#  'carlos',
#  'here',
#  'phone',
#  'vibrate',
#  'acting',
#  'might',
#  'hear',
#  'texts',
#  'oh',
#  'got',
#  'job',
#  'spjanuary',
#  'male',
#  'sale',
#  'hot',
#  'gay',
#  'chat',
#  'cheaper',
#  '08709222922',
#  'national',
#  'rate',
#  '5p',
#  'min',
#  'cheap',
#  '8p',
#  'peak',
#  '08712460324',
#  '10p',
#  'yeah',
#  'use',
#  'gt',
#  'atm',
#  'register',
#  'anyway',
#  'help',
#  'let',
#  'know',
#  'nationwide',
#  'auto',
#  'centre',
#  'something',
#  'like',
#  'newport',
#  'road',
#  'liked',
#  'them',
#  'number',
#  'has',
#  'been',
#  'awarded',
#  '2000',
#  'prize',
#  'guaranteed',
#  '09061790121',
#  'land',
#  'line',
#  'claim',
#  '3030',
#  'valid',
#  '12hrs',
#  'mah',
#  'tomorrow',
#  'she',
#  'believe',
#  'wat',
#  've',
#  'hey',
#  'sat',
#  'sec',
#  'somebody',
#  'want',
#  'yup',
#  'izzit',
#  'still',
#  'raining',
#  'heavily',
#  'mrt',
#  'outside',
#  're',
#  'going',
#  'finn',
#  'prasanth',
#  'ettans',
#  'mother',
#  'passed',
#  'away',
#  'last',
#  'pray',
#  'family',
#  'enjoy',
#  'showers',
#  'possessiveness',
#  'poured',
#  'loved',
#  'bcoz',
#  'world',
#  'lies',
#  'golden',
#  'truly',
#  'really',
#  'into',
#  'skateboarding',
#  'despite',
#  'fact',
#  'gets',
#  'thrown',
#  'off',
#  'winds',
#  'bandages',
#  'all',
#  'his',
#  'arms',
#  'five',
#  'minutes',
#  'us',
#  'connection',
#  'itself',
#  'decimal',
#  'refund',
#  'bill',
#  'congratulations',
#  '500',
#  'cd',
#  '125gift',
#  'entry',
#  'wkly',
#  'tncs',
#  'com1win150ppmx3age16',
#  'mum',
#  'robinson',
#  'already',
#  'meh',
#  'both',
#  'fine',
#  'awesome',
#  'deal',
#  'gate',
#  'charles',
#  'uh',
#  'thought',
#  'watch',
#  'thats',
#  'kind',
#  'get4an18th',
#  'loves',
#  'safe',
#  'trip',
#  'nigeria',
#  'happiness',
#  'very',
#  'soon',
#  'company',
#  'share',
#  'moments',
#  'fancy',
#  'meetin',
#  'cha',
#  'hav',
#  'lil',
#  'beverage',
#  'ring',
#  'l8r',
#  'quite',
#  'tired',
#  'pist',
#  'pete',
#  'didn',
#  'mean',
#  'post',
#  'wrote',
#  'many',
#  'other',
#  'times',
#  'ritten',
#  'stuff',
#  'sit',
#  'feeling',
#  'time',
#  'left',
#  'hit',
#  'wasn',
#  'checked',
#  'car',
#  'were',
#  'bored',
#  'wouldn',
#  'clean',
#  'fold',
#  'laundry',
#  'etc',
#  'least',
#  'bed',
#  'mapquest',
#  'look',
#  'dogwood',
#  'drive',
#  'tiny',
#  'street',
#  'where',
#  'parking',
#  'lot',
#  'yalrigu',
#  'heltini',
#  'iyo',
#  'kothi',
#  'shared',
#  'things',
#  'wit',
#  'body',
#  'even',
#  'uttered',
#  'abt',
#  'trusting',
#  'these',
#  'others',
#  'plz',
#  'nxt',
#  'dont',
#  'those',
#  'words',
#  'becoz',
#  'its',
#  'jan',
#  'whn',
#  'al',
#  'ofice',
#  'cn',
#  'fr',
#  'duffer',
#  'some',
#  'pix',
#  'would',
#  'top',
#  'bottom',
#  'beautiful',
#  'truth',
#  'against',
#  'gravity',
#  'carefully',
#  'heart',
#  'feels',
#  'light',
#  'someone',
#  'heavy',
#  'leaves',
#  'buzz',
#  'goes',
#  'miss',
#  'babe',
#  'long',
#  'moment',
#  'together',
#  'loving',
#  'smile',
#  'lara',
#  'loan',
#  'dunno',
#  'remember',
#  'mayb',
#  'tmr',
#  'wats',
#  'opinion',
#  'character',
#  'wasted',
#  'muz',
#  'chiong',
#  'sun',
#  'liao',
#  'bring',
#  'home',
#  'wendy',
#  'allo',
#  'braved',
#  'buses',
#  'taken',
#  'trains',
#  'triumphed',
#  'ham',
#  'jolly',
#  'rest',
#  'hmmm',
#  'players',
#  'selected',
#  'flippin',
#  'yet',
#  'board',
#  'working',
#  'issue',
#  'overheating',
#  'reslove',
#  'software',
#  'inst',
#  'pending',
#  'around',
#  'clock',
#  '1000',
#  'girls',
#  'local',
#  'who',
#  'virgins',
#  '4fil',
#  'sexual',
#  'theirs',
#  'cute',
#  '69911',
#  '50p',
#  'nope',
#  'since',
#  'ayo',
#  'travelled',
#  'forgotten',
#  'guy',
#  'maybe',
#  'yck',
#  'called',
#  'dad',
#  'oredi',
#  'alright',
#  'head',
#  'deep',
#  'sigh',
#  'surprised',
#  'haven',
#  'gone',
#  'net',
#  'cafe',
#  'don',
#  'office',
#  'pm',
#  'hospital',
#  'asked',
#  '3mobile',
#  '0870',
#  'chatlines',
#  'inclu',
#  'mins',
#  'india',
#  'cust',
#  'servs',
#  'sed',
#  'yes',
#  'l8er',
#  'mega',
#  'bailiff',
#  'due',
#  'days',
#  '250',
#  '800',
#  'bathe',
#  'getting',
#  'threats',
#  'sales',
#  'executive',
#  'shifad',
#  'as',
#  'raised',
#  'complaint',
#  'message',
#  'increase',
#  'chance',
#  'winning',
#  'queen',
#  'royal',
#  'wedding',
#  'reached',
#  'railway',
#  'happen',
#  'probably',
#  'gonna',
#  'wee',
#  'bit',
#  'pa',
#  'aha',
#  'waited',
#  'yesterday',
#  'flights',
#  'europe',
#  'b4',
#  '10th',
#  'sept',
#  'friend',
#  '09050000555',
#  'ba128nnfwfly150ppm',
#  'shopping',
#  'spree',
#  'shop',
#  '80878',
#  'custcare',
#  '08715705022',
#  '1x150p',
#  'wk',
#  'btw',
#  'alibi',
#  'cutting',
#  'hair',
#  'whole',
#  'way',
#  'evening',
#  'ttyl',
#  'watching',
#  'house',
#  'entertaining',
#  'hugh',
#  'laurie',
#  'stick',
#  'indeed',
#  'especially',
#  'responding',
#  'went',
#  'diwali',
#  'makes',
#  'died',
#  'people',
#  'seems',
#  'special',
#  'first',
#  'sight',
#  'remain',
#  'till',
#  'maintain',
#  'life',
#  'ends',
#  'cr',
#  'ya',
#  'knw',
#  'vl',
#  'giv',
#  '1st',
#  'salary',
#  'lol',
#  'forgot',
#  'eh',
#  'wow',
#  'healthy',
#  'old',
#  'airport',
#  'rd',
#  'thk',
#  'else',
#  'bathing',
#  'dog',
#  '2nd',
#  'tried',
#  '1450',
#  '09053750005',
#  '310303',
#  'cs',
#  'sms',
#  '08718725756',
#  '140ppm',
#  'may',
#  'pub',
#  'browsin',
#  'compulsory',
#  'movies',
#  'laptop',
#  'eat',
#  'fo',
#  'senor',
#  'thank',
#  'calling',
#  'happy',
#  'onam',
#  'sirji',
#  'remembered',
#  'met',
#  'insurance',
#  'person',
#  'qatar',
#  'insha',
#  'allah',
#  'rakhesh',
#  'ex',
#  'tata',
#  'aig',
#  'joined',
#  'tissco',
#  'tayseer',
#  'able',
#  'late',
#  'weeks',
#  'plans',
#  'ah',
#  'poor',
#  'baby',
#  'urfeeling',
#  'bettersn',
#  'luv',
#  'probthat',
#  'overdose',
#  'careful',
#  'spk',
#  'sn',
#  'lots',
#  'lovejen',
#  'xxx',
#  'hi',
#  'crashed',
#  'cuddled',
#  'sofa',
#  'show',
#  'yourself',
#  'put',
#  'new',
#  'pictures',
#  'facebook',
#  'grumpy',
#  'mom',
#  'better',
#  'lying',
#  'always',
#  'jokes',
#  'boo',
#  'moms',
#  'making',
#  'tortilla',
#  'soup',
#  'yummmm',
#  'under',
#  'standing',
#  'actually',
#  'talk',
#  'boss',
#  'place',
#  'year',
#  'fixed',
#  'kept',
#  'telling',
#  'hoped',
#  'regretted',
#  'pls',
#  'nelson',
#  'bb',
#  'comin',
#  'expecting',
#  'aint',
#  'didnt',
#  'snow',
#  'freezing',
#  'windy',
#  'bishan',
#  'nearer',
#  'buy',
#  'early',
#  'gotta',
#  'park',
#  'stayin',
#  'trouble',
#  'stranger',
#  'saw',
#  'sorted',
#  'bloke',
#  'gona',
#  'girl',
#  'mr',
#  'thinks',
#  '2getha',
#  'shag',
#  'interested',
#  'sextextuk',
#  'xxuk',
#  'suzy',
#  '69876',
#  'txts',
#  'per',
#  'msg',
#  'website',
#  'eatin',
#  'shower',
#  'wif',
#  'carry',
#  'num',
#  '98321561',
#  'familiar',
#  'bec',
#  'temple',
#  'na',
#  'after',
#  'completed',
#  'degree',
#  'joining',
#  'finance',
#  'spoke',
#  'maneesha',
#  'satisfied',
#  'experience',
#  'reply',
#  'toll',
#  'tyler',
#  'minor',
#  'crisis',
#  'sooner',
#  'asap',
#  'box',
#  'dependents',
#  'once',
#  'fishrman',
#  'woke',
#  'mrng',
#  'dark',
#  'while',
#  'found',
#  'sack',
#  'ful',
#  'stones',
#  'strtd',
#  'throwin',
#  'thm',
#  'in2',
#  'sea',
#  'pass',
#  'atlast',
#  'jus',
#  '1stone',
#  'rose',
#  'tht',
#  'nt',
#  'diamonds',
#  'moral',
#  'wake',
#  'hello',
#  'moving',
#  'flat',
#  'arrange',
#  'lamp',
#  'caroline',
#  'darlin',
#  'ive',
#  'finished',
#  'college',
#  'finish',
#  'kate',
#  'chillaxin',
#  'break',
#  'noe',
#  'searching',
#  'breather',
#  'promise',
#  'wont',
#  'granted',
#  'fulfil',
#  'wonderful',
#  'blessing',
#  'midnight',
#  'earliest',
#  'macho',
#  'budget',
#  'bold',
#  'dollars',
#  'fb',
#  'list',
#  'princess',
#  'kitty',
#  'shaved',
#  'natural',
#  'ahhhh',
#  'woken',
#  'bad',
#  'dream',
#  'tho',
#  'comedy',
#  'guess',
#  'im',
#  'adult',
#  'learn',
#  'real',
#  'danger',
#  'peeps',
#  'using',
#  'drugs',
#  'they',
#  'comment',
#  'secret',
#  'admirer',
#  'looking',
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
tfidf_transformer.idf_
# Out:
# array([7.22545811, 6.29114888, 8.93020621, ..., 8.93020621, 8.93020621,
#        8.93020621])

# %%
# get test docs into a list
docs_test=sms['text'].tolist()

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        fname = feature_names[idx]
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
# you only needs to do this once
feature_names=cv.get_feature_names()

# get the document that we want to extract keywords from
doc=docs_test[0]

#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

#sort the tf-idf vectors by descending order of scores
sorted_items=sort_coo(tf_idf_vector.tocoo())

#extract only the top n; n here is 10
keywords=extract_topn_from_vector(feature_names,sorted_items,1000)

# %%
print("\n=====SMS=====")
print(docs_test[0])

for k in keywords:
    print(k, keywords[k])
# Out:
# =====SMS=====
# Hope you are having a good week. Just checking in
# checking 0.517
# having 0.426
# week 0.356
# hope 0.354
# good 0.302
# just 0.269
# are 0.255
# in 0.212
# you 0.163

# %%
# put the common code into several methods
def get_keywords(idx):

    #generate tf-idf for the given document
    tf_idf_vector=tfidf_transformer.transform(cv.transform([docs_test[idx]]))

    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only the top n; n here is 10
    keywords=extract_topn_from_vector(feature_names,sorted_items,10)
    
    return keywords

def print_results(idx,keywords):
    # now print the results
    print("\n=====Title=====")
    print(docs_test[idx])

    for k in keywords:
        print(k,keywords[k])

# %%
msg = ""
for i in range(1000):
    message = docs_test[i]
    msg = msg + message
    continue

print (msg)
msg.tolist()
keywords=get_keywords(msg)
print_results(msg,keywords)
# Out:
# Hope you are having a good week. Just checking inK..give back my thanks.Am also doing in cbe only. But have to pay.complimentary 4 STAR Ibiza Holiday or £10,000 cash needs your URGENT collection. 09066364349 NOW from Landline not to lose out! Box434SK38WP150PPM18+okmail: Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppmAiya we discuss later lar... Pick u up at 4 is it?Are you this much buzyPlease ask mummy to call fatherMarvel Mobile Play the official Ultimate Spider-man game (£4.50) on ur mobile right now. Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaperfyi I'm at usf now, swing by the room wheneverSure thing big man. i have hockey elections at 6, shouldn€˜t go on longer than an hour thoughI anything lor...By march ending, i should be ready. But will call you for sure. The problem is that my capital never complete. How far with you. How's work and the ladiesHmm well, night night K I'll be sure to get up before noon and see what's whatHa ha cool cool chikku chikku:-):-DB-)Darren was saying dat if u meeting da ge den we dun meet 4 dinner. Cos later u leave xy will feel awkward. Den u meet him 4 lunch lor.He dint tell anything. He is angry on me that why you told to abi.Up to u... u wan come then come lor... But i din c any stripes skirt...U can WIN £100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.ldew.com SkillGame,1Winaweek, age16.150ppermessSubscription2mro i am not coming to gym machan. Goodnight.ARR birthday today:) i wish him to get more oscar.Reading gud habit.. Nan bari hudgi yorge pataistha ertini kano:-)I sent my scores to sophas and i had to do secondary application for a few schools. I think if you are thinking of applying, do a research on cost also. Contact joke ogunrinde, her school is one me the less expensive onesCould you not read me, my Love ? I answered youSo what did the bank say about the money?Well if I'm that desperate I'll just call armand againFuuuuck I need to stop sleepin, supSo how's the weather over there?Ok thanx...Ok.ok ok..then..whats ur todays plan1Apple/Day=No Doctor. 1Tulsi Leaf/Day=No Cancer. 1Lemon/Day=No Fat. 1Cup Milk/day=No Bone Problms 3 Litres Watr/Day=No Diseases Snd ths 2 Whom U Care..:-)Sorry, I'll call laterWill do. Was exhausted on train this morning. Too much wine and pie. You sleep well tooU have won a nokia 6230 plus a free digital camera. This is what u get when u win our FREE auction. To take part send NOKIA to 83383 now. POBOX114/14TCR/W1 16Ron say fri leh. N he said ding tai feng cant make reservations. But he said wait lor.Call me when you/carlos is/are here, my phone's vibrate is acting up and I might not hear textsOh k :)why you got job then whats up?SPJanuary Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)Yeah you should. I think you can use your gt atm now to register. Not sure but if there's anyway i can help let me know. But when you do be sure you are ready.Nationwide auto centre (or something like that) on Newport road. I liked them thereHe is there. You call and meet himYeah sure I'll leave in a minURGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppmMah b, I'll pick it up tomorrowThen she dun believe wat?I've sent u my part..Hey so whats the plan this sat? Can you just come in for a sec? There's somebody here I want you to seeYup. Izzit still raining heavily cos i'm in e mrt i can't c outside.I think we're going to finn's now, comeOur Prasanth ettans mother passed away last night. Just pray for her and family.Enjoy the showers of possessiveness poured on u by ur loved ones, bcoz in this world of lies, it is a golden gift to be loved truly..He's really into skateboarding now despite the fact that he gets thrown off  ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-d7f27bd67982> in <module>
#       6
#       7 print (msg)
# ----> 8 msg.tolist()
#       9 keywords=get_keywords(msg)
#      10 print_results(msg,keywords)
#
# AttributeError: 'str' object has no attribute 'tolist'
